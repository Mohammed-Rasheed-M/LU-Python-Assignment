# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed-Rasheed-M/LetsUpgrade-Python-Assignment-Submission/blob/main/LetsUpgrade_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question 1:**
# **Use OPEN Weather Map API,**

# %%
import requests
#importing os

from datetime import datetime

api_key = 'e2f4884ca76678ca8833fdad2661ea41'
location = input("Enter the city name: ")

complete_api_link = "https://api.openweathermap.org/data/2.5/weather?q="+location+"&appid="+api_key
api_link = requests.get(complete_api_link)
api_data = api_link.json()

#creating variables to store and display data
temp_city = ((api_data['main']['temp']) - 273.15)
weather_desc = api_data['weather'][0]['description']
hmdt = api_data['main']['humidity']
wind_spd = api_data['wind']['speed']
date_time = datetime.now().strftime("%d %b %Y | %I:%M:%S %p")

print ("-------------------------------------------------------------")
print ("Weather Stats for - {}  || {}".format(location.upper(), date_time))
print ("-------------------------------------------------------------")

print ("Current temperature is: {:.2f} deg C".format(temp_city))
print ("Current weather desc  :",weather_desc)
print ("Current Humidity      :",hmdt, '%')
print ("Current wind speed    :",wind_spd ,'kmph')
with open('weather.txt','a') as f:
  f.write(str(api_link.content))
  f.write("\n")
# Out:
# Enter the city name: london
# -------------------------------------------------------------
# Weather Stats for - LONDON  || 08 Jul 2021 | 03:02:23 PM
# -------------------------------------------------------------
# Current temperature is: 20.26 deg C
# Current weather desc  : broken clouds
# Current Humidity      : 69 %
# Current wind speed    : 4.63 kmph

# %% [markdown]
# **Question 2**
# **Tic tac toe Game**

# %%
import random
def display_board(board):
  print(f'''
    \t\t     POSITIONS\n
    \t{board[7]}|{board[8]}|{board[9]}  \t  \t7 | 8 | 9
    \t---+---+---            ---+---+---    
    \t{board[4]}|{board[5]}|{board[6]}  \t=>\t4 | 5 | 6
    \t---+---+---            ---+---+---     
    \t{board[1]}|{board[2]}|{board[3]}  \t  \t1 | 2 | 3
  ''')
def valid_input():
  while True:
    place_marker = input("Enter the Position number : ")
    if place_marker != " ":
      if place_marker.isdigit():
        if int(place_marker) in range(1, 10):
          return int(place_marker)
        print("Invalid Position")
      else:
        print("Enter numbers between 1-9")
        continue
def valid_position(turn, board, player):
  print(f"{turn} chance")
  position = valid_input()
  while True:
    if board[position] == '   ':
      board[position] = ' ' + dict(player)[turn] + ' '
      display_board(board)
      break
    else:
      print("The position is already filled")
      position = valid_input()
def valid_position(turn, board, player):
  print(f"{turn} chance")
  position = valid_input()
  while True:
    if board[position] == '   ':
      board[position] = ' ' + dict(player)[turn] + ' '
      display_board(board)
      break
    else:
      print("The position is already filled")
      position = valid_input()
def check_win(board):
  check = 0
  if (board[1] == board[2] == board[3] != '   ' or board[4] == board[5] == board[6] != '   ' or board[7] == board[8] == board[9] != '   ' or 
      board[1] == board[4] == board[7] != '   ' or board[2] == board[5] == board[8] != '   ' or board[3] == board[6] == board[9] != '   ' or 
      board[1] == board[5] == board[9] != '   ' or board[3] == board[5] == board[7] != '   '):
    check = 1
  return check
def match(board, mark, player):
  mark_1, mark_2 = mark[random.randint(0, 1)]
  player_turn = 0 if mark_1 == 'X' else 1
  print(f"\t{player[player_turn][0]} plays first")
  display_board(board)
  for i in range(9):
    if not i % 2:
      turn = player[player_turn][0]
      valid_position(turn, board, player)
    else:
      turn = player[not player_turn][0]
      valid_position(turn, board, player)
    if i >= 4:
      if check_win(board):
        display_board(board)
        print(f"\tCongratulation !!!\n\t{turn} WON the Match")
        break
    if i == 8:
      print("It's a Tie")
print("\t\tTIC-TAC-TOE")
player_1 = input("\n1st Player Name : ").upper()
player_2 = input("2nd Player Name : ").upper()
players = [player_1, player_2]

mark = [('O', 'X'), ('X', 'O')]
replay = "yes"
while replay == "yes":
  board = ['', '   ', '   ', '   ', '   ', '   ', '   ', '   ', '   ', '   ']
  print("\nLet the Match Begin !!!\nBest of Luck to both the Players !!!")
  num = random.randint(0, 1)
  player = [(players[num], 'X'), (players[not num], 'O')]
  print(f"\n\t{players[num]} is X and {players[not num]} is O")
  match(board, mark, player)
  replay = input("\nDo you want to play again? (yes/no)\n").lower()

print("\n\t\tThanks for playing !!!")
# Out:
# 		TIC-TAC-TOE
#
# 1st Player Name : Adil
# 2nd Player Name : Rauf
#
# Let the Match Begin !!!
# Best of Luck to both the Players !!!
#
# 	ADIL is X and RAUF is O
# 	RAUF plays first
#
#     		     POSITIONS
#
#     	   |   |     	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	   |   |     	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	   |   |     	  	1 | 2 | 3
#
# RAUF chance
# Enter the Position number : 2
#
#     		     POSITIONS
#
#     	   |   |     	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	   |   |     	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	   | O |     	  	1 | 2 | 3
#
# ADIL chance
# Enter the Position number : 3
#
#     		     POSITIONS
#
#     	   |   |     	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	   |   |     	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	   | O | X   	  	1 | 2 | 3
#
# RAUF chance
# Enter the Position number : 1
#
#     		     POSITIONS
#
#     	   |   |     	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	   |   |     	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	 O | O | X   	  	1 | 2 | 3
#
# ADIL chance
# Enter the Position number : 4
#
#     		     POSITIONS
#
#     	   |   |     	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	 X |   |     	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	 O | O | X   	  	1 | 2 | 3
#
# RAUF chance
# Enter the Position number : 5
#
#     		     POSITIONS
#
#     	   |   |     	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	 X | O |     	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	 O | O | X   	  	1 | 2 | 3
#
# ADIL chance
# Enter the Position number : 6
#
#     		     POSITIONS
#
#     	   |   |     	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	 X | O | X   	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	 O | O | X   	  	1 | 2 | 3
#
# RAUF chance
# Enter the Position number : 7
#
#     		     POSITIONS
#
#     	 O |   |     	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	 X | O | X   	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	 O | O | X   	  	1 | 2 | 3
#
# ADIL chance
# Enter the Position number : 8
#
#     		     POSITIONS
#
#     	 O | X |     	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	 X | O | X   	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	 O | O | X   	  	1 | 2 | 3
#
# RAUF chance
# Enter the Position number : 9
#
#     		     POSITIONS
#
#     	 O | X | O   	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	 X | O | X   	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	 O | O | X   	  	1 | 2 | 3
#
#
#     		     POSITIONS
#
#     	 O | X | O   	  	7 | 8 | 9
#     	---+---+---            ---+---+---
#     	 X | O | X   	=>	4 | 5 | 6
#     	---+---+---            ---+---+---
#     	 O | O | X   	  	1 | 2 | 3
#
# 	Congratulation !!!
# 	RAUF WON the Match
#
# Do you want to play again? (yes/no)
# no
#
# 		Thanks for playing !!!
